# %% [markdown]
# This is used for experiment and testing the functionalities. The productionized version is packged in `random_data_generator.py` and `read_print_data.py` for the challenges.

# %%
import random
import string
import os

# %% [markdown]
# ## Challenge A

# %%
def get_random_object(max_obj_length = 15):
    """
    Get the random objects from the supported list including: integer, float, alphabet and alphanumeric.
    
    Args:
        max_obj_length: the length of objects (note: integer part of float & excluding spaces in alphanumeric)
    
    Return:
        random_obj: random object
    """
    
    obj_type = random.choice(["integer", "float", "alphabet", "alphanumeric"])
    obj_length = random.randint(2, max_obj_length)
    random_number = random.random()
    
    if obj_type == "integer":
        rand_obj = int(random_number*(10**obj_length))
    
    elif obj_type == "float":
        rand_obj = round(random_number*(10**obj_length), 5)
        
    elif obj_type == "alphabet":
        rand_obj = "".join(random.choices(string.ascii_letters, k = obj_length))
        
    elif obj_type == "alphanumeric":
        rand_obj = "".join(random.choices(string.ascii_letters + string.digits, k = obj_length-2))
        rand_obj += random.choice(string.ascii_letters)
        rand_obj += random.choice(string.digits)
        
        # Add random spaces before and after the alphanumeric object, total spaces <= 10
        n_before = random.randint(0, 10)
        n_after = random.randint(0, 10 - n_before)
        rand_obj = n_before*" " + rand_obj + n_after*" "
    else:
        raise ValueError(f"Not supported object type: '{obj_type}'")
    
    return rand_obj

def write_file(content, file_path):
    """
    Write the content to file. If file is not exsited, it uses 'w' mode else 'a' (append) mode.
    
    Args:
        content: content to write
        file_path: path to store the file
    
    Returns:
        None
    """
    write_mode = "a" if os.path.exists(file_path) else "w"
    with open(file_path, write_mode) as f:
        if write_mode == "w":
            f.write(content)
        else:
            f.write(", " + content)

# %%
# Write object by batch of 500 objects, so it can scale to write the large file
# to prevent out of memory

obj_cnt = 0
batch = 500
rand_objs = []

file_path = "output.txt"
file_size = os.path.getsize(file_path) if os.path.exists(file_path) else 0

one_mb = int(1<<20)
while file_size < 1*one_mb:
    
    rand_objs.append(str(get_random_object()))
    obj_cnt += 1
    
    if obj_cnt % batch == 0:
        content = ", ".join(rand_objs)
        write_file(content, file_path)
        file_size = os.path.getsize(file_path)
        rand_objs = []

print(f"Total generated objects: {obj_cnt}")
print(f"File size: {round(file_size/one_mb, 3)} MB")
# Out:
# Total generated objects: 77000
# File size: 1.002 MB

# %% [markdown]
# ## Challenge B

# %%
def is_float(obj):
    """
    Check if object is float datatype or not
    
    Args:
        obj: input object in string
    
    Returns:
        True if it is float, else False
    """
    try:
        float(obj)
    except ValueError:
        return False
    return True

with open(file_path, "r") as f:
    content = f.read()
    objs = [obj.strip() for obj in content.split(",")]

for obj in objs:
    if obj.isnumeric():
        result = f"{obj} - integer"
    elif obj.isalpha():
        result = f"{obj} - alphabetical strings"
    elif obj.isalnum():
        result = f"{obj} - alphanumeric"
    elif is_float(obj):
        result = f"{obj} - real number"
    else:
        raise ValueError(f"Unknown object type: '{result}', please check your code.")
    print(result)
# Out:
# 370542 - integer
# 24880914888.62755 - real number
# 865.86942 - real number
# nx - alphabetical strings
# XgLuAtfa - alphabetical strings
# 633 - integer
# DhwMZPHMF - alphabetical strings
# 509364754 - integer
# 613033 - integer
# VZ3wyaKFEu2 - alphanumeric
# 75.87174 - real number
# FseGKyDa - alphabetical strings
# 417415943.33144 - real number
# OVKflZlXuse - alphabetical strings
# 203.68023 - real number
# LZvvmjW - alphabetical strings
# lWimnyHlhL3n0 - alphanumeric
# 6795527.64026 - real number
# 2280249510 - integer
# rnBegTqwxLmpJ - alphabetical strings
# 68.12385 - real number
# wnGc4p4pSW5Z4q7 - alphanumeric
# 401792227 - integer
# 96283244535.16113 - real number
# 19902091836 - integer
# 909884 - integer
# wI3uSUvCX9 - alphanumeric
# MPhUbYNPN - alphabetical strings
# 67960771180402.49 - real number
# 2515799041637 - integer
# zKq6DaeYJlUw3O3 - alphanumeric
# 10024 - integer
# zcZAWXrLrJF - alphabetical strings
# 858495773166220 - integer
# 535199597458.9899 - real number
# 9582 - integer
# 24242335367409 - integer
# fEnLXdlsgoOZxFY - alphabetical strings
# tB - alphabetical strings
# 631666.36036 - real number
# yfgQ4ZbJRfk36n8 - alphanumeric
# SXyrld - alphabetical strings
# 629.81383 - real number
# 364 - integer
# XFVlHrbUIikMO - alphabetical strings
# 844094451356466 - integer
# solaStdEzWxlWr - alphabetical strings
# p1oG4EbB6 - alphanumeric
# TF1rw8OE3 - alphanumeric
# xzMYjZnha - alphabetical strings
# ViDk8P2IEPQ1eQ4 - alphanumeric
# WLwGe7nu1ihcw2 - alphanumeric
# N4JEuXZNNt6 - alphanumeric
# Ph3gnxb5n5 - alphanumeric
# 97421243 - integer
# 9576693009 - integer
# vuth8stIw7 - alphanumeric
# 646 - integer
# 35768348 - integer
# 541220599473223.56 - real number
# oWknM - alphabetical strings
# G5Y5b7 - alphanumeric
# OlWJ6 - alphanumeric
# COEDPR1el7j4 - alphanumeric
# NOpmBCGtRQd - alphabetical strings
# 51287018 - integer
# nUVVXRXGcP0Z6 - alphanumeric
# AQnOVvKSsYHfs3 - alphanumeric
# 17172418198635 - integer
# jnIDmUiOv - alphabetical strings
# 7856 - integer
# 107893938635 - integer
# 4273904763723 - integer
# 37261667 - integer
# xxMcLq5 - alphanumeric
# lwpIKrRbJdmsqme - alphabetical strings
# 18895544088766 - integer
# 382323413892.5131 - real number
# hAXb - alphabetical strings
# 3318369636.15592 - real number
# 39360741622695.32 - real number
# AYAoLlfbqsS - alphabetical strings
# rnLB8kY48for9 - alphanumeric
# 945866819160914.1 - real number
# 9065788065 - integer
# DcwBIJSeD - alphabetical strings
# 0r5l5JEdRClZ8 - alphanumeric
# 9860432 - integer
# y2OKssCvK4 - alphanumeric
# 58936.94475 - real number
# 44 - integer
# sLqYJDglBNApxV - alphabetical strings
# 391931593267214 - integer
# 68701666105397.74 - real number
# mGF - alphabetical strings
# mPvrisANhI3zAY0 - alphanumeric
# 5277230111 - integer
# 2054368 - integer
# 89169085529 - integer
# 9140224766 - integer
# 9.74165 - real number
# JjgqxSSbgP - alphabetical strings
# 21026494080363.668 - real number
# NMVBrg0FRTP3 - alphanumeric
# pUWSHF8r55k1 - alphanumeric
# gF - alphabetical strings
# rLCQ3 - alphanumeric
# jA - alphabetical strings
# 120211 - integer
# LwuvYDa - alphabetical strings
# 70.42273 - real number
# 4238636.2113 - real number
# 484642645322920.25 - real number
# 812.57563 - real number
# LdCRbI0NuE2 - alphanumeric
# EURQMGIIVrwKIL8 - alphanumeric
# 654364973 - integer
# gLkLr - alphabetical strings
# uvkfjejgJ5YDPo6 - alphanumeric
# nhLnaCsAIR - alphabetical strings
# 217265817635.04605 - real number
# 9708664 - integer
# a2 - alphanumeric
# nqgcQ7 - alphanumeric
# lLyFjspaiJcZPE - alphabetical strings
# IgRyOomnXw - alphabetical strings
# 29679298323029 - integer
# 854878725146 - integer
# 592190089593271 - integer
# 5408440771 - integer
# 711 - integer
# 923190027.08487 - real number
# 11956785 - integer
# BsNPJNH - alphabetical strings
# bTRqPHkyumi - alphabetical strings
# 861018558748 - integer
# ZUaO - alphabetical strings
# 646163993.37494 - real number
# kXW40LN3 - alphanumeric
# 4658.76568 - real number
# 5449830349.96564 - real number
# 370708778649 - integer
# lyYouwaKGz24u7 - alphanumeric
# 16029402779471 - integer
# MFWRtnYpmD4 - alphanumeric
# 19272.87057 - real number
# iHwB5KVidupjrd7 - alphanumeric
# 4785351.13213 - real number
# 95188154 - integer
# gt - alphabetical strings
# yclMbcjiIxhTz - alphabetical strings
# GUqMhpZ1 - alphanumeric
# GO7Au1NNv6 - alphanumeric
# 240 - integer
# 761054523800 - integer
# 64606917 - integer
# 7076 - integer
# QgDNmM4 - alphanumeric
# dA4YP4 - alphanumeric
# RXKXosKRbUrl - alphabetical strings
# 155521536043.5921 - real number
# AiiqJ7 - alphanumeric
# 4811459954.46737 - real number
# IRBepaxB - alphabetical strings
# mNI - alphabetical strings
# egdvQWtSN - alphabetical strings
# 5187215369174.077 - real number
# 3061790590.52476 - real number
# X6MYPRV3bW5 - alphanumeric
# 37 - integer
# 6547289008995 - integer
# 550603 - integer
# 1770756224 - integer
# 65314332.69789 - real number
# PXyDiBvXlekHInP - alphabetical strings
# 570859950412299 - integer
# n7 - alphanumeric
# 9139500885528 - integer
# hWzhITX0 - alphanumeric
# 8004186 - integer
# 372939181964571.9 - real number
# EoUcYDsR - alphabetical strings
# tXtaMyCwsMjmcJJ - alphabetical strings
# 16974 - integer
# Qjw4i3 - alphanumeric
# 3597204651622 - integer
# V1GTvj6h6 - alphanumeric
# gIusI5 - alphanumeric
# mYqWZ - alphabetical strings
# nUxb6SEhmyCbrQ4 - alphanumeric
# zgyBVQufARDMJAv - alphabetical strings
# 34609874387143.48 - real number
# 20040767716.56567 - real number
# 6306061257.97547 - real number
# eTb2 - alphanumeric
# iAMnR7 - alphanumeric
# bjgcM1 - alphanumeric
# 148821876 - integer
# KK4 - alphanumeric
# 42654 - integer
# K8jtER2WxOY8 - alphanumeric
# r1LdtxQrW2 - alphanumeric
# 21044.06354 - real number
# 18711.99642 - real number
# 97 - integer
# roqXYsDEsSmB7 - alphanumeric
# bqIGd8 - alphanumeric
# ioqvvkoy - alphabetical strings
# oG - alphabetical strings
# 8140953748 - integer
# 94795508 - integer
# FoYhUIykfx - alphabetical strings
# zJJyAvkW - alphabetical strings
# 4796477163501.999 - real number
# 3051 - integer
# 58561110.17355 - real number
# pZk873MRPIa4 - alphanumeric
# ODBOgAAjb6MwkV3 - alphanumeric
# VzZzKdgOKfWTiLM - alphabetical strings
# sbYFItuaOLCD5 - alphanumeric
# 9vOWs4MFbOHJV1 - alphanumeric
# vfJ6rrcDTB2 - alphanumeric
# 298061675 - integer
# 3488167 - integer
# 9835330013 - integer
# vHPlYNDzGeD - alphabetical strings
# 8977023536250.184 - real number
# 3zwg9 - alphanumeric
# KlufqCrlsaC - alphabetical strings
# 414 - integer
# MosErzQ9ru8TI2 - alphanumeric
# PAvsTsya - alphabetical strings
# LzaS - alphabetical strings
# 421257710.06397 - real number
# ML3 - alphanumeric
# 88840812 - integer
# 6395292 - integer
# VwSKv3 - alphanumeric
# 890444338947.5189 - real number
# i1 - alphanumeric
# OTG9HWusLwPE5 - alphanumeric
# RXTHV - alphabetical strings
# qe - alphabetical strings
# tC7 - alphanumeric
# 51 - integer
# Z8TyELdd66adtu2 - alphanumeric
# dzJN - alphabetical strings
# 682598640624.1979 - real number
# 487.33221 - real number
# 3aAYzprOM0 - alphanumeric
# GVAgYH1jp0 - alphanumeric
# 6bWvwtzJ8 - alphanumeric
# Jcm - alphabetical strings
# PRflrDm - alphabetical strings
# 3603.65439 - real number
# mT7 - alphanumeric
# JJregXM - alphabetical strings
# 69GrAczpuFh0 - alphanumeric
# 212631826.34072 - real number
# y1 - alphanumeric
# bhnnaA5HU9 - alphanumeric
# QL19cdgo97O3aQ5 - alphanumeric
# 61358 - integer
# 6736033575381.914 - real number
# 83714 - integer
# nd1 - alphanumeric
# hEVIlnSuyIDwWnH - alphabetical strings
# hbhtkmhbNtaD1 - alphanumeric
# 5487 - integer
# 7428931006722.3125 - real number
# 605378613545986.4 - real number
# 198722736935.17517 - real number
# qif6wfD9Eue3li1 - alphanumeric
# elFKrvF2 - alphanumeric
# 86519494.41044 - real number
# eseTfRzeDch - alphabetical strings
# 37357135.77374 - real number
# 2489025891935.133 - real number
# 877834 - integer
# 6103.89056 - real number
# 95268376381442 - integer
# 397121689.08954 - real number
# QxadDvKbva - alphabetical strings
# UyXVDrsR1xzfvn6 - alphanumeric
# ejiD - alphabetical strings
# LqVCSAeV - alphabetical strings
# 794519766570060 - integer
# 9670736750 - integer
# 767.5546 - real number
# 5iCQflyM5 - alphanumeric
# eAIodJcWLaWQU - alphabetical strings
# 4537441836 - integer
# 760994256.70003 - real number
# 68.88961 - real number
# n2 - alphanumeric
# hHBkZxIXLKkyga8 - alphanumeric
# 7769138642.63015 - real number
# 7756851239 - integer
# 9882634729 - integer
# 38210675.87198 - real number
# ShaNcXGo - alphabetical strings
# 2823876476.93327 - real number
# 71910973.57064 - real number
# ivhvy0w7 - alphanumeric
# 6985408939679 - integer
# cJ - alphabetical strings
# 5600264.64144 - real number
# 4840785132698.34 - real number
# YtCeRtVG - alphabetical strings
# PV6zMSqQkCnL5 - alphanumeric
# 66163430318.30274 - real number
# yjNzdHa - alphabetical strings
# 31603823000.50746 - real number
# 85909 - integer
# cY - alphabetical strings
# zKtp - alphabetical strings
# 733018.23688 - real number
# sUXk - alphabetical strings
# mtFxLkzwQrWH - alphabetical strings
# xc1PYDG6TQnLqu3 - alphanumeric
# ApDwtsPRo - alphabetical strings
# 3918857945820 - integer
# tEYGw6bTRwAv2 - alphanumeric
# UyI7 - alphanumeric
# 26307 - integer
# ZJi - alphabetical strings
# 4820944 - integer
# 884677944383 - integer
# 8835.67548 - real number
# duSK0JX3z6 - alphanumeric
# wkoge4RVEFqLE5 - alphanumeric
# kgJIJahsJwSoSx0 - alphanumeric
# fokYNSmJx - alphabetical strings
# KWPyhwg - alphabetical strings
# 711 - integer
# bp3s3mOPkW1W4 - alphanumeric
# yRAAvtbTz - alphabetical strings
# 341325116459402.0 - real number
# 98439108128 - integer
# SrWRKYVi - alphabetical strings
# 88602828545527 - integer
# zoCHQQkXn9 - alphanumeric
# 6034015713431.265 - real number
# 6MsXVbumdL89cE5 - alphanumeric
# 1478538253357 - integer
# ZUA - alphabetical strings
# 990889800 - integer
# 8 - integer
# nUu0sL5 - alphanumeric
# 5J1 - alphanumeric
# ZygBIu29G9ERU4 - alphanumeric
# 8393734992 - integer
# 47.92398 - real number
# 84140470486081.1 - real number
# 63.35235 - real number
# ldXfOpWN - alphabetical strings
# QhnGVRerO - alphabetical strings
# 1350613495594 - integer
# 6465129341 - integer
# WOGMKx - alphabetical strings
# 287.34384 - real number
# 587004540890 - integer
# jDmZ - alphabetical strings
# 6420872081 - integer
# KpimXPVlvvwb - alphabetical strings
# TZNkoHCL - alphabetical strings
# xqQpui1CX4 - alphanumeric
# 453241163349186 - integer
# ZlFqVv - alphabetical strings
# 9843418714770.256 - real number
# 580133203817.2122 - real number
# 72823.70707 - real number
# WV6u7 - alphanumeric
# 155165813347146 - integer
# SJumdZCCES - alphabetical strings
# 922673 - integer
# jOxcujzUaBEmPi - alphabetical strings
# fXaGdQFKYm - alphabetical strings
# 37664369554 - integer
# zCBnQTS - alphabetical strings
# 614752273 - integer
# rokMGUiblC - alphabetical strings
# CucsbRHazEbUay - alphabetical strings
# oTtiyPNbKRYj - alphabetical strings
# 60629 - integer
# 98594.76357 - real number
# dwFANJbIZpaEGD - alphabetical strings
# DDtmeU - alphabetical strings
# 428449.52245 - real number
# vMVbGhyVa - alphabetical strings
# 96602965.33738 - real number
# 82331656536.00027 - real number
# KHXlRPp2 - alphanumeric
# LZz2APE6 - alphanumeric
# 5399518338.6428 - real number
# bDBXLmMntehz - alphabetical strings
# GvRCmgfgOFI - alphabetical strings
# 518862 - integer
# 3928021522.3376 - real number
# zRdWYC6SNl8 - alphanumeric
# 98520836006.27234 - real number
# 31399 - integer
# AQDKHAZ8fa8 - alphanumeric
# 848387 - integer
# 451473.91258 - real number
# Dep - alphabetical strings
# 47413 - integer
# 35519 - integer
# 9kgy4IX4 - alphanumeric
# 3090853483527.8213 - real number
# 53766474933229 - integer
# xGwtyPi6ZZCxD5 - alphanumeric
# 3809.24016 - real number
# vpNF - alphabetical strings
# 1154.32353 - real number
# 43491679213.57987 - real number
# AZyWvHdTh0 - alphanumeric
# TNLRfNjwuM - alphabetical strings
# 9052972613857 - integer
# 5Gp0LZq6 - alphanumeric
# 66536749638.10123 - real number
# 38318447413563.4 - real number
# 7274650 - integer
# MX2 - alphanumeric
# 3313797752.4788 - real number
# XKtDR - alphabetical strings
# 2979604847 - integer
# 22223924924547 - integer
# Iqyf3 - alphanumeric
# 95280164854.01471 - real number
# XuoLQws - alphabetical strings
# gfNHa0bA0 - alphanumeric
# vJYHbTjWdR3 - alphanumeric
# Rk7O2XdAJYyTV3 - alphanumeric
# kPhubgvLlKtSI - alphabetical strings
# yvsSn97GS2h4 - alphanumeric
# JOiTSWHAcuKogu - alphabetical strings
# YQMBpKWQLRbY - alphabetical strings
# 76510222854898.88 - real number
# jfkKTGO - alphabetical strings
# 13158050088812 - integer
# 3qU2B4xY8 - alphanumeric
# EYHJRruU - alphabetical strings
# g7 - alphanumeric
# 68EjeQZLu3J2 - alphanumeric
# lQnh - alphabetical strings
# nHO2Z6YFPb5 - alphanumeric
# KKK - alphabetical strings
# 7 - integer
# 51376520786 - integer
# sJ8w7 - alphanumeric
# 5797886322.99574 - real number
# AWqpsustOkk - alphabetical strings
# 6367917041 - integer
# MfYmZXt - alphabetical strings
# 111941932937 - integer
# 6398438968326.048 - real number
# 762886338 - integer
# WroaD - alphabetical strings
# Orm1yztlpvS9 - alphanumeric
# 33.85831 - real number
# 7313 - integer
# 839025027809 - integer
# 2403510.53478 - real number
# Kqx - alphabetical strings
# MLTkq7 - alphanumeric
# 2402571.66943 - real number
# 301259 - integer
# 4REGb9eIuh9 - alphanumeric
# KudmtIJwsN - alphabetical strings
# 171675206.17031 - real number
# cQBVUguIcSJGkN - alphabetical strings
# 1005359093192 - integer
# s9JPwMbj2YFwXJ5 - alphanumeric
# 258532458 - integer
# 759534003.14181 - real number
# hhFpbgwcYo - alphabetical strings
# 8110758594876 - integer
# tdZnSjeI2t8 - alphanumeric
# 55320682 - integer
# 4034032965312.624 - real number
# mmfYffQuwRhC - alphabetical strings
# ZiFqq15R8 - alphanumeric
# ESku7 - alphanumeric
# eWCOnQ - alphabetical strings
# 66.94089 - real number
# Nb6VMov8vDuedX1 - alphanumeric
# 94902.55772 - real number
# ujNFYO9N6 - alphanumeric
# Rbw - alphabetical strings
# 491201.30343 - real number
# 59497729775864.2 - real number
# 45041060405.69088 - real number
# en - alphabetical strings
# 417375042 - integer
# 279540 - integer
# jBghmDavQ - alphabetical strings
# 80 - integer
# iaLvaryMAQs9 - alphanumeric
# 21.26871 - real number
# Dp - alphabetical strings
# 61.75276 - real number
# 59622973786.7886 - real number
# 793 - integer
# S6HoT8UzVfQP2 - alphanumeric
# 465999775.63747 - real number
# tKprozMHsFsHHVx - alphabetical strings
# 35028467 - integer
# 62825906.50817 - real number
# 1101110419.93699 - real number
# 1S7to7 - alphanumeric
# C8 - alphanumeric
# XmPJUBtGFke - alphabetical strings
# 86224658 - integer
# 37730877.85454 - real number
# gnfMR2mk5 - alphanumeric
# 27641.77441 - real number
# njmgtJqrhzZg - alphabetical strings
# 3504939804385.033 - real number
# SvRXVLeNCuSHe - alphabetical strings
# cpOAbX - alphabetical strings
# 245278115977009 - integer
# 74647 - integer
# LTtRDpPMTUQke - alphabetical strings
# 8189072656717 - integer
# 306 - integer
# eUSzEwgz5 - alphanumeric
# 2aiKrU3 - alphanumeric
# 13922417 - integer
# 10 - integer
# 77641955687 - integer
# VP0 - alphanumeric
# 61771791830550.36 - real number
# 16220107350 - integer
# 52149751 - integer
# 89413.78482 - real number
# 90.03179 - real number
# O2ramVAsbWWWrO3 - alphanumeric
# kOoIDi - alphabetical strings
# cctX - alphabetical strings
# 15 - integer
# 335554 - integer
# d17p4we5S4 - alphanumeric
# 921230950384.7008 - real number
# idrCC - alphabetical strings
# LpzMlpLiAamr - alphabetical strings
# gnjMvG - alphabetical strings
# 2084444 - integer
# QpvdzaxTuOTwh - alphabetical strings
# knhFF - alphabetical strings
# 21688415640.08755 - real number
# 6859 - integer
# 999.78785 - real number
# 19876663837 - integer
# TeLQ0iu0zdj1 - alphanumeric
# 7727250734 - integer
# 6989599.28756 - real number
# 2497690787 - integer
# TwFRRmEn8 - alphanumeric
# hn - alphabetical strings
# 54741026957 - integer
# 193 - integer
# 47279464857584 - integer
# Emu1 - alphanumeric
# 21962758 - integer
# 889291773384 - integer
# 885402 - integer
# vZrAlpRppvuB - alphabetical strings
# 79711717.34169 - real number
# ONCdkVROLiGC - alphabetical strings
# 6923.80465 - real number
# FyqTGsD0zfjgN9 - alphanumeric
# 23783390.8323 - real number
# mIlkyghteiu - alphabetical strings
# 409.11671 - real number
# H2 - alphanumeric
# vf0SQX8 - alphanumeric
# ZsZRsIqKi - alphabetical strings
# 1958 - integer
# sCYLWkboIdHxtc - alphabetical strings
# SN - alphabetical strings
# iH - alphabetical strings
# jwbMMrH - alphabetical strings
# 4554.30891 - real number
# AnlYZkdYCIPjjP - alphabetical strings
# 34699 - integer
# CM0 - alphanumeric
# rNWhaZnZMYH - alphabetical strings
# bnVNIt - alphabetical strings
# 80.13676 - real number
# g7iH5kub2R58Z0 - alphanumeric
# 696950151355 - integer
# shGWfhuaAdCO - alphabetical strings
# fXV - alphabetical strings
# DcjHdbdT - alphabetical strings
# 416333255 - integer
# 1Q2DH7tU2 - alphanumeric
# 622509647900481.9 - real number
# 17.27146 - real number
# 4R8 - alphanumeric
# 434877126507045.8 - real number
# 690.09379 - real number
# 60787 - integer
# 670.37825 - real number
# 508269 - integer
# yLHEv3 - alphanumeric
# 605.1916 - real number
# 87 - integer
# 858229858897.5623 - real number
# 132371695.90263 - real number
# 26588336.47943 - real number
# ZgIrXQsopD - alphabetical strings
# 836431422428.827 - real number
# 533.73305 - real number
# woA0 - alphanumeric
# XgPW6iHvo0QP9 - alphanumeric
# 79930.82332 - real number
# 7195894 - integer
# 83517755 - integer
# 662540824200 - integer
# 5598 - integer
# BQAdWnUl - alphabetical strings
# 478662414213.34033 - real number
# nhyNZ7 - alphanumeric
# XBudsSMarluq - alphabetical strings
# 456891837926769.0 - real number
# eZjKKNUWPMsGw - alphabetical strings
# 90446514947.49445 - real number
# CHal - alphabetical strings
# fJmFaJONQySu - alphabetical strings
# 7L8 - alphanumeric
# 941854768990927.2 - real number
# 3399010.76788 - real number
# 9786157319797 - integer
# Ay - alphabetical strings
# uOPWUM4y2 - alphanumeric
# 463496090.10651 - real number
# WrfA7 - alphanumeric
# 598638191 - integer
# 18.73002 - real number
# 161886 - integer
# gYBfeqYXyF - alphabetical strings
# 35 - integer
# wGdseymLosLwsC - alphabetical strings
# roqEAnR - alphabetical strings
# 8041753 - integer
# U2R05rhD81wxWS0 - alphanumeric
# 478629528137976 - integer
# SdEtUfjPoHD - alphabetical strings
# ONaZd7 - alphanumeric
# HNFkCxrU - alphabetical strings
# 994355465884051.9 - real number
# 58576 - integer
# 2584069 - integer
# Pe1 - alphanumeric
# 2366223.99851 - real number
# 9992642757.67018 - real number
# 39695050 - integer
# 6874 - integer
# MhOGnYuk - alphabetical strings
# BAhAYeRhM - alphabetical strings
# 6760 - integer
# thODZL - alphabetical strings
# 3338.20557 - real number
# 38323 - integer
# 52269435233566 - integer
# 236890749957 - integer
# fXsPGHOTaaVse - alphabetical strings
# 37068415680260.125 - real number
# pedxgLntC - alphabetical strings
# 746349.34104 - real number
# 584.22113 - real number
# kVdMAuoRFnsbSm - alphabetical strings
# 4417414 - integer
# toYSbWR - alphabetical strings
# INHWEZMxVv - alphabetical strings
# 63756.03842 - real number
# 55639764383 - integer
# 2684530 - integer
# Omdq - alphabetical strings
# Cxgri - alphabetical strings
# 3623676.30866 - real number
# q44CCmRCH9 - alphanumeric
# 461847580677 - integer
# 6870147 - integer
# OlJkaWbtSu - alphabetical strings
# mBz3 - alphanumeric
# A6 - alphanumeric
# 3139275666293.2397 - real number
# 17844438953.97219 - real number
# njd - alphabetical strings
# 347802 - integer
# 415931195.5623 - real number
# 6314529057 - integer
# 8851.27164 - real number
# 123956.4214 - real number
# 13460493939821 - integer
# oYAvkQMcavouBg - alphabetical strings
# 737058716626 - integer
# IEv - alphabetical strings
# 943 - integer
# 715251520284 - integer
# 80320312645 - integer
# 62080244 - integer
# 55558758245.83687 - real number
# 6849773548.37283 - real number
# 4083.79849 - real number
# 5007245 - integer
# WVKCgOr2 - alphanumeric
# DOn - alphabetical strings
# 36.22331 - real number
# MfDfE - alphabetical strings
# irKcS2 - alphanumeric
# 583 - integer
# 348888456.99612 - real number
# KgixsdLhXdnR - alphabetical strings
# 2287.63081 - real number
# 7sMR0QhXgbZ9 - alphanumeric
# 4337636200518 - integer
# 9709031 - integer
# YS - alphabetical strings
# 582705636.21893 - real number
# 47752365413 - integer
# 26438651903223.21 - real number
# zNehJTNZYDuxS - alphabetical strings
# mPdoerjknTZeuwu - alphabetical strings
# W4 - alphanumeric
# zvgbezpErFp2N4 - alphanumeric
# 125067619.24018 - real number
# 1509812536 - integer
# 13890007615608 - integer
# 280415509282817.66 - real number
# 2zxIKZGnVe1 - alphanumeric
# nF4A9 - alphanumeric
# dOdbKEGjUK - alphabetical strings
# HdaCljx14naWqS4 - alphanumeric
# 3945209731.69587 - real number
# vSoxMmDENmMBKEM - alphabetical strings
# 638937 - integer
# C8dt58xi5wqJ0 - alphanumeric
# 6124970636.0226 - real number
# QsHEU - alphabetical strings
# opsWJ8p6 - alphanumeric
# 94466879526.28264 - real number
# oMXCnsuC - alphabetical strings
# ijDxCVWQRdWh - alphabetical strings
# KU - alphabetical strings
# 3500313885 - integer
# 256538068 - integer
# xQLNWDUhQtF - alphabetical strings
# 87673.89368 - real number
# 280478772980 - integer
# RpEABsHIMyuCWsv - alphabetical strings
# gbgWn8 - alphanumeric
# r67jdEGFy2 - alphanumeric
# 5wu9 - alphanumeric
# enNrlfkoArPQXc - alphabetical strings
# Mdlqh - alphabetical strings
# 84779722 - integer
# 13879199391327.945 - real number
# 9901070623368 - integer
# AsglfL8 - alphanumeric
# 33028813.58307 - real number
# 88 - integer
# 5438.5535 - real number
# 9321417093 - integer
# 89876 - integer
# 229373.51683 - real number
# 7923530 - integer
# hBGxLiAkvoQpfxX - alphabetical strings
# vaRpxVO - alphabetical strings
# 704054753995.8772 - real number
# OvcKpCwHRkY - alphabetical strings
# 6azo8JV5 - alphanumeric
# jouJYPDN5 - alphanumeric
# 880824220935 - integer
# tdwldv - alphabetical strings
# 4173.10595 - real number
# 5049330 - integer
# qMygDZKAGHV - alphabetical strings
# WLoucmtrtLkXFB - alphabetical strings
# 7251982945929.163 - real number
# btUdwm - alphabetical strings
# cGrwMoVuUzgLM - alphabetical strings
# mDlhInigZfVirFK - alphabetical strings
# DmWbIyA0McHKH5 - alphanumeric
# twRFI6Fha4 - alphanumeric
# 5AW5 - alphanumeric
# AlPC - alphabetical strings
# RXtg1 - alphanumeric
# zxCY3NwUA4 - alphanumeric
# 509431987 - integer
# nlavvfoV - alphabetical strings
# hevox6 - alphanumeric
# PJOgTYWKTfRoRt - alphabetical strings
# DTUdwfUF6T4 - alphanumeric
# 47 - integer
# 43965975 - integer
# 92.14958 - real number
# 33005356271 - integer
# QUoM2 - alphanumeric
# 15383855.70302 - real number
# 9703652.44138 - real number
# l2 - alphanumeric
# ZobN3yc8 - alphanumeric
# OBDsu - alphabetical strings
# XiatYvC - alphabetical strings
# 9568.47786 - real number
# jgUoBkGC - alphabetical strings
# 7807462757 - integer
# 678906143590.3438 - real number
# gxAdPrGHYZj - alphabetical strings
# 8662908 - integer
# jECpj - alphabetical strings
# 3M2 - alphanumeric
# mpptyu3 - alphanumeric
# 14.7678 - real number
# YZD0Di2 - alphanumeric
# 41 - integer
# 246538105996.70044 - real number
# yLkWAMbP5 - alphanumeric
# 778433189.9875 - real number
# 4572400763583 - integer
# 37722313.66695 - real number
# 536125160740.59015 - real number
# 20967618.34457 - real number
# 976505560.42705 - real number
# 66.08758 - real number
# 36034401.36296 - real number
# 33.06728 - real number
# 314554 - integer
# 9167853.42299 - real number
# ILqsxaSzVp - alphabetical strings
# 7986641.4004 - real number
# hm - alphabetical strings
# 57506443675051.77 - real number
# d4xle5 - alphanumeric
# vyDe - alphabetical strings
# Ggf2VZGY1 - alphanumeric
# 5443874 - integer
# cdxoRG - alphabetical strings
# R5C2i0 - alphanumeric
# TG0ve6AxD4z3 - alphanumeric
# 2854165.22615 - real number
# 385016240.06367 - real number
# AsFPOXkskWlNS - alphabetical strings
# MRYBNXkZqdEX - alphabetical strings
# 73709238809.88777 - real number
# 21426024 - integer
# 268.77266 - real number
# SLHL9u9n0dYUx6 - alphanumeric
# 915.40148 - real number
# 6143256014440.858 - real number
# 611213.61156 - real number
# 81717272.2688 - real number
# lr004CvlOz8 - alphanumeric
# xesSaOw7rw8 - alphanumeric
# 99590717290 - integer
# RhTMgoDLrRpXqX - alphabetical strings
# 619296581886222.0 - real number
# 916412579 - integer
# 851825510973 - integer
# ESyWNzNATYWewa - alphabetical strings
# 772 - integer
# tq6WxF8 - alphanumeric
# WRsJMqRfbvGQS - alphabetical strings
# 60386.47192 - real number
# BU - alphabetical strings
# 2470647.91608 - real number
# BFClHUr2F0 - alphanumeric
# 36128313158088 - integer
# 579769 - integer
# 109783039 - integer
# cBLaYJiNjU - alphabetical strings
# wpELoAfsOFAY - alphabetical strings
# vZCDrKDPdhVTh1 - alphanumeric
# 829700541375.564 - real number
# 2U3tz1 - alphanumeric
# 55.22384 - real number
# 88107491474596.25 - real number
# 1723.92626 - real number
# 25317.29331 - real number
# 8788457.76633 - real number
# cAf0 - alphanumeric
# 66586597348.39269 - real number
# oqVuV6YmBSQD4 - alphanumeric
# 27940129.12632 - real number
# DqGUFcuaKVoddzm - alphabetical strings
# ctPmFiLcKwzgrDJ - alphabetical strings
# E3 - alphanumeric
# sfZTzji4 - alphanumeric
# tMqO86Z4 - alphanumeric
# 605111097 - integer
# 711 - integer
# r8MVTe3 - alphanumeric
# xa - alphabetical strings
# nopTRAz - alphabetical strings
# 1514149 - integer
# On - alphabetical strings
# Y1 - alphanumeric
# 83.26667 - real number
# 7908427432548.505 - real number
# 92305815 - integer
# 65277864587651 - integer
# 4rw5D7 - alphanumeric
# 937399526 - integer
# 561602209 - integer
# PgBrqpBmZQCsW - alphabetical strings
# D1 - alphanumeric
# pBDbnwB0o0 - alphanumeric
# 558062.77597 - real number
# luCCYRlzS - alphabetical strings
# 131430084048 - integer
# 634516511325089.4 - real number
# aTmrNiSrH - alphabetical strings
# saXb - alphabetical strings
# 28 - integer
# 12269349513 - integer
# 62631588.00526 - real number
# RQpAaOAirs2 - alphanumeric
# 4716 - integer
# 10924 - integer
# YexunuDIUwI - alphabetical strings
# iPuUNaPysSQMA - alphabetical strings
# 1444618455.09984 - real number
# gzUqY5h7VES1 - alphanumeric
# 8 - integer
# hW0 - alphanumeric
# 1852931670599 - integer
# AslopgVdldwTZY - alphabetical strings
# 3415788.99455 - real number
# evGj - alphabetical strings
# 5935 - integer
# ogMP2F2LlUdX0 - alphanumeric
# 1381663696.92936 - real number
# NG8wbHrJXAiE8 - alphanumeric
# xiFARU0 - alphanumeric
# xPCksUM - alphabetical strings
# 84468425 - integer
# 8884874232653.438 - real number
# iSl - alphabetical strings
# 88.87944 - real number
# 5925364109403.755 - real number
# RsFRJrsYYfO6 - alphanumeric
# QxKuhzObj - alphabetical strings
# 24bQUB7pf52M4 - alphanumeric
# rjhcnQhpu - alphabetical strings
# zPXU - alphabetical strings
# XRkSlcpiENs - alphabetical strings
# 8724566490 - integer
# 8578 - integer
# 6722915557211 - integer
# AcksGXo1aI8 - alphanumeric
# OCeQ8 - alphanumeric
# UjxvYdog - alphabetical strings
# fPAxfUBp - alphabetical strings
# 795728001982.5074 - real number
# 451333936143500.5 - real number
# aAQzoao - alphabetical strings
# 962550480.08532 - real number
# MhrFB - alphabetical strings
# 80 - integer
# iLaU22Iesh7pi7 - alphanumeric
# edM44teF6 - alphanumeric
# 4o7wXkCC9Rp6 - alphanumeric
# UmtHjv6 - alphanumeric
# 7027468578.995 - real number
# 108134347943525.72 - real number
# lFDfr - alphabetical strings
# 88766685254275 - integer
# FndQ1 - alphanumeric
# EHnHghrg8 - alphanumeric
# aO - alphabetical strings
# 93642775599939 - integer
# mDGGDcpPYmZA - alphabetical strings
# BkezPd - alphabetical strings
# 489.36622 - real number
# 71038918466865 - integer
# APLJRAhbZd6 - alphanumeric
# Izp9SLI2 - alphanumeric
# 37806678 - integer
# cWvUwj2 - alphanumeric
# JRfQJBByRVdI - alphabetical strings
# ZVlWKHQCB - alphabetical strings
# 272114598487 - integer
# jvgoJxSaCsoHMp - alphabetical strings
# 48.23576 - real number
# 41553.26052 - real number
# hoksgCv - alphabetical strings
# 621170085799782 - integer
# IAgObNhnOFYA - alphabetical strings
# 6500.37329 - real number
# ng8 - alphanumeric
# 28512 - integer
# EJk - alphabetical strings
# 4359439482347.418 - real number
# 73041643570438 - integer
# 7633561442.68906 - real number
# 566068 - integer
# hzGlG2 - alphanumeric
# gRoYfJAi - alphabetical strings
# 187914085873.86172 - real number
# 60042757.80021 - real number
# hwkuyduy - alphabetical strings
# 877112866835675 - integer
# 8078134.22581 - real number
# 74791783.00979 - real number
# 991 - integer
# vzEOPtOsfCC - alphabetical strings
# RCO - alphabetical strings
# BIbNXoXIY - alphabetical strings
# IFHWXnXr - alphabetical strings
# fDvAA0I3 - alphanumeric
# 780191.76407 - real number
# 60935227466.60142 - real number
# 5488364 - integer
# fiicL - alphabetical strings
# 8772388468.99496 - real number
# 866659351 - integer
# 569937 - integer
# 4.82869 - real number
# 1795870806282 - integer
# 419465 - integer
# 0KWlMR6 - alphanumeric
# AFoY - alphabetical strings
# 77087 - integer
# 582066720667653 - integer
# YhKWD9Aruiuo6 - alphanumeric
# gf1l6WNiSqQjA8 - alphanumeric
# KeIt2 - alphanumeric
# nmMFIFDnnam - alphabetical strings
# b3yY2q9 - alphanumeric
# 4780390392783 - integer
# 2966.76687 - real number
# 54215.49091 - real number
# 970 - integer
# BmoBtMXekllVPr - alphabetical strings
# 572.20745 - real number
# 9378572297.59898 - real number
# CxzZgOtPAh7 - alphanumeric
# 92.69726 - real number
# fZ - alphabetical strings
# LMRlbg - alphabetical strings
# hMJye - alphabetical strings
# 550.74738 - real number
# 5711342079029 - integer
# TaUAqjYI - alphabetical strings
# yltX - alphabetical strings
# 69082742.97711 - real number
# oXKh - alphabetical strings
# tr - alphabetical strings
# 8ea8QOUlpjrr2 - alphanumeric
# 85568203 - integer
# XBe - alphabetical strings
# VTsOC - alphabetical strings
# tmfktaMLsFgHtk - alphabetical strings
# CMDtInGpTiYTNHg - alphabetical strings
# nCsA4C7FN3BR4H8 - alphanumeric
# 660 - integer
# 787 - integer
# 2508891452236.778 - real number
# 52228448075969.7 - real number
# 67197030224170 - integer
# bpDQYcIPCp - alphabetical strings
# 59913977.59365 - real number
# 4001 - integer
# 2836660 - integer
# CdMvTghLbitr2 - alphanumeric
# 910251.53797 - real number
# 350938347143 - integer
# 2636703132 - integer
# uBsojYG - alphabetical strings
# 723699 - integer
# 987038.5497 - real number
# 678714546.72883 - real number
# RvknAMqDqlpwZQ0 - alphanumeric
# 283971185.99814 - real number
# 40.5428 - real number
# XwvEYEJjWptVuPF - alphabetical strings
# MvaKcrQTRMyfu - alphabetical strings
# lT9 - alphanumeric
# 99318240 - integer
# 9330 - integer
# KYNX9 - alphanumeric
# 71121285.19269 - real number
# 150.7327 - real number
# IarRRt - alphabetical strings
# 84 - integer
# 2 - integer
# DAU33RQuPeC2X7 - alphanumeric
# 0g7pXbJ4Og3 - alphanumeric
# 9978701264.95542 - real number
# 7498229052102 - integer
# Sg2H2iTd9QDhRP5 - alphanumeric
# xge4OveySUqR3 - alphanumeric
# 86 - integer
# 99 - integer
# 6740900748 - integer
# 957093897570.7247 - real number
# fuSmH4PlS5QQwE6 - alphanumeric
# 934.64019 - real number
# 7GKO6 - alphanumeric
# 37479525 - integer
# 22 - integer
# L3q7 - alphanumeric
# 715909309.00361 - real number
# 8039929347083 - integer
# 24795675611882 - integer
# 5928557377703 - integer
# 172571322.34295 - real number
# ebtUXizQlGyhzZ - alphabetical strings
# 9464269086.29505 - real number
# PCUS - alphabetical strings
# ih3 - alphanumeric
# 956548 - integer
# 5824 - integer
# 96384395137 - integer
# R2ylkH1JeH8 - alphanumeric
# 510027 - integer
# iYSubpAVY - alphabetical strings
# 900769009.56647 - real number
# 155405 - integer
# ZMm8 - alphanumeric
# 681438406.42202 - real number
# XEUFunMMxahRS - alphabetical strings
# bYTD - alphabetical strings
# w2j9 - alphanumeric
# 2550580798855 - integer
# kgsYXWlNL - alphabetical strings
# dIxqOxTzs - alphabetical strings
# 422.9086 - real number
# YKCzRkjYAJiVk - alphabetical strings
# 731520225.21348 - real number
# zXCSSogNovMevAM - alphabetical strings
# 8384.25834 - real number
# iF7 - alphanumeric
# Hu - alphabetical strings
# 876879172686 - integer
# nmBSLqudxYhzJWP - alphabetical strings
# QniNeIf1n4 - alphanumeric
# 4902424146364 - integer
# GLVPdZPZksnjASu - alphabetical strings
# cxxsBUVAHg - alphabetical strings
# KndMEJEvweS - alphabetical strings
# 9238 - integer
# hfnIDRWMomGqs - alphabetical strings
# JdwnLBTtB - alphabetical strings
# XsgRPhRTn9PGA7 - alphanumeric
# 2006.19306 - real number
# wPdjaGGF3S6 - alphanumeric
# 746 - integer
# 13 - integer
# SbtjYdDz - alphabetical strings
# 0MoL1h0Im2 - alphanumeric
# ooM3 - alphanumeric
# DrHDftQ - alphabetical strings
# 810541 - integer
# 461498843 - integer
# 1321053684337.492 - real number
# 21573163 - integer
# 5140455571 - integer
# 249238004.52258 - real number
# 75.86709 - real number
# wDIckeUzeuvREM - alphabetical strings
# 69 - integer
# ESc - alphabetical strings
# 215020158594393.06 - real number
# 34.69627 - real number
# RrdSscE - alphabetical strings
# DyMHTNRFJFbQ3 - alphanumeric
# 457864577445 - integer
# ZxmA3 - alphanumeric
# Uh8 - alphanumeric
# 50.00599 - real number
# 344 - integer
# FwFLTH - alphabetical strings
# fzlGLmyuHLPWOxz - alphabetical strings
# 5823324419.34423 - real number
# nSvcMFcDo6Kdq9 - alphanumeric
# 4.76319 - real number
# 19772206741.35963 - real number
# 6404336240336.268 - real number
# 7719483.96587 - real number
# vfdbHeValpuKfbH - alphabetical strings
# 5AuWctR9b4SFq5 - alphanumeric
# CiC - alphabetical strings
# BOiSLTn - alphabetical strings
# 312960.80385 - real number
# 170092917.05898 - real number
# rCazjETjiMO - alphabetical strings
# 229445.2066 - real number
# 24.93332 - real number
# mWta - alphabetical strings
# 5132 - integer
# 5143610 - integer
# FabpJqUmTaBNw - alphabetical strings
# wlOXpcUcvu - alphabetical strings
# fke - alphabetical strings
# V6 - alphanumeric
# 17445910.32025 - real number
# 80773640 - integer
# 4412574945.91573 - real number
# 98.11078 - real number
# uUmnhBEZSSeb - alphabetical strings
# 195023.01268 - real number
# IzGqnFRA - alphabetical strings
# pnN - alphabetical strings
# wXmEIi21uTj42D5 - alphanumeric
# nXbTNSo - alphabetical strings
# NonVzdASqWf4 - alphanumeric
# 45330 - integer
# 3VUEnCri1 - alphanumeric
# euuZPi - alphabetical strings
# 6512322104682.834 - real number
# HVzbXaYjI3 - alphanumeric
# 3531291142 - integer
# fkWdFoZQsGEh1 - alphanumeric
# JSwSscuEg - alphabetical strings
# 656165016.18044 - real number
# x3 - alphanumeric
# 65020871954116.74 - real number
# EvQlOwGUT - alphabetical strings
# R6P2 - alphanumeric
# 563643648359222.6 - real number
# Hui7ci0 - alphanumeric
# 91zO60gUb1 - alphanumeric
# 256109549927952.44 - real number
# 500409064960 - integer
# 288582880449598.56 - real number
# dOW - alphabetical strings
# ZfBSkYyEaPdmG4 - alphanumeric
# 584938057886 - integer
# UqiiImtxf - alphabetical strings
# jod - alphabetical strings
# OPvIvo - alphabetical strings
# 89213255 - integer
# 3812935680233 - integer
# ijrQDx6oV5 - alphanumeric
# KNjkvuWJpesOoyK - alphabetical strings
# xeJeP - alphabetical strings
# rg0P9 - alphanumeric
# 1331158821749.421 - real number
# vAjRPYmlcPDUCp - alphabetical strings
# QskNE9CGiB6e5 - alphanumeric
# mP2hvf5 - alphanumeric
# xzuhaYU3 - alphanumeric
# MFeZOuDyJ - alphabetical strings
# 84402458 - integer
# B6l7 - alphanumeric
# 23875264 - integer
# 301098643563409 - integer
# 4232593.57027 - real number
# 40690423434326.47 - real number
# 94309 - integer
# viflReHcyZGf - alphabetical strings
# F6 - alphanumeric
# 3NtEoCK3BEpqC2 - alphanumeric
# 7953767 - integer
# 347474468647543 - integer
# ti - alphabetical strings
# 880.88582 - real number
# 46 - integer
# 549 - integer
# nURoyyd - alphabetical strings
# drbxEsesHYUv - alphabetical strings
# 960289.10179 - real number
# 7WQaesPwVdh5 - alphanumeric
# 8954660564.89158 - real number
# FGcSnBvbQWOnT - alphabetical strings
# pNdxwtmBCqVPu - alphabetical strings
# szPcWHXuUfmwiqe - alphabetical strings
# kzdQv2g6t5wgt9 - alphanumeric
# aHLehDP - alphabetical strings
# HUwqBKYlEAJe - alphabetical strings
# 36504972099266 - integer
# 304 - integer
# 931536.32911 - real number
# 15209574538014.447 - real number
# IDiflBsjctAx - alphabetical strings
# vxcbpCvk - alphabetical strings
# 62.15084 - real number
# eUBl - alphabetical strings
# MvcMNmTSAHNxise - alphabetical strings
# 6bMmejGGyvF5 - alphanumeric
# UWjYU1XluotRWN5 - alphanumeric
# oOwQlS - alphabetical strings
# npVvS2M1 - alphanumeric
# 320942962.90118 - real number
# 52009516977898.8 - real number
# eqGTek - alphabetical strings
# 629 - integer
# DkrNBMH9 - alphanumeric
# 1099.01441 - real number
# tfmc - alphabetical strings
# 8370258458.07509 - real number
# HhNwoKuMwmxWC - alphabetical strings
# ZOaTtUhlFyxg - alphabetical strings
# 1637973280567.5483 - real number
# CSBVMezaalb - alphabetical strings
# ZeH1 - alphanumeric
# Lpv9etkd5d4 - alphanumeric
# qDjVYeYU - alphabetical strings
# 7PO2 - alphanumeric
# 6549 - integer
# 8666646196 - integer
# 28 - integer
# 666956.53072 - real number
# 5687 - integer
# 848122.25939 - real number
# 490610.38897 - real number
# 182358.88214 - real number
# UAQs0K3 - alphanumeric
# JVqIAtGIkTU - alphabetical strings
# Mk7 - alphanumeric
# 443537.67933 - real number
# 8177.26941 - real number
# 516886551.71009 - real number
# 9xT7 - alphanumeric
# A2QyLC6 - alphanumeric
# 50401.35399 - real number
# fzuicvtUFzdD6 - alphanumeric
# 70 - integer
# EE6LbnyTP4 - alphanumeric
# NXiYi - alphabetical strings
# 2579260581 - integer
# XzTVhSd4 - alphanumeric
# 48210337555295.26 - real number
# pZFAACleLnLs - alphabetical strings
# 1995023381 - integer
# 9893297892614.688 - real number
# A61bWZsA0 - alphanumeric
# 4101758670.68816 - real number
# avyNSw - alphabetical strings
# 378244280628 - integer
# dLlI - alphabetical strings
# rsAm5uXEF2 - alphanumeric
# re - alphabetical strings
# 949062291722 - integer
# 482190028058913.9 - real number
# ohlehZ - alphabetical strings
# 0ePdB1 - alphanumeric
# n2apy64yGglEbl3 - alphanumeric
# 59198622020511.46 - real number
# 3G9 - alphanumeric
# 8.04576 - real number
# 5556291787313 - integer
# 5990.23493 - real number
# 79839109096 - integer
# eRXeAACIk - alphabetical strings
# 24401877.94692 - real number
# uYguQqBGNLR - alphabetical strings
# f0 - alphanumeric
# 7456.07392 - real number
# QkUBMrLsJswjS - alphabetical strings
# 189869.05348 - real number
# LISmDYWMQJgyss - alphabetical strings
# 1542241.42423 - real number
# 4866233655.62743 - real number
# fwub8 - alphanumeric
# 21367211613 - integer
# eUMNu - alphabetical strings
# XUUtyGd - alphabetical strings
# CUG - alphabetical strings
# 777 - integer
# 267728.57749 - real number
# 88169998855 - integer
# aTXyoGMoCJUu - alphabetical strings
# HoiNpcZqfqZaXd9 - alphanumeric
# QQLazXzI - alphabetical strings
# Wtng9Y2cRr7 - alphanumeric
# Is - alphabetical strings
# ZTqAGoRH - alphabetical strings
# 635137493587.8998 - real number
# viNrgMZrJWoXS - alphabetical strings
# 5885911390383 - integer
# 127 - integer
# 956193044 - integer
# 358.7576 - real number
# 154.15457 - real number
# FyeMyDLPtYAI - alphabetical strings
# 72 - integer
# 964 - integer
# 17201 - integer
# hDjRnQdm - alphabetical strings
# njGCPK7 - alphanumeric
# 66076723863 - integer
# 261337532.82374 - real number
# pn6a9eKkO8 - alphanumeric
# ALEhqSAnLnvNcWI - alphabetical strings
# 20977 - integer
# iaDstDmYuy - alphabetical strings
# j9 - alphanumeric
# 536053044934.494 - real number
# i0VL8SJFNB8E2 - alphanumeric
# 74248477012661 - integer
# 8702534899.39867 - real number
# WLtNTQqHcMVYg - alphabetical strings
# wHD - alphabetical strings
# yOlAPJua - alphabetical strings
# 476043 - integer
# 43708 - integer
# ufrdTNWBQq - alphabetical strings
# 2383408680940.9414 - real number
# fX3i4MGGvTE7 - alphanumeric
# 4770781146939.672 - real number
# 17663391 - integer
# xEpTSrIGfeklkSY - alphabetical strings
# Njv2 - alphanumeric
# 873.59607 - real number
# 9330149341150.402 - real number
# BN - alphabetical strings
# 477785.0816 - real number
# 72.0111 - real number
# 1956383085611.113 - real number
# 5566482.16455 - real number
# 66156992037892 - integer
# 4984588387 - integer
# O0rPSBEY4 - alphanumeric
# 7318248.61577 - real number
# RfVyoB - alphabetical strings
# 66689033587.87061 - real number
# 4814244318 - integer
# 222048406989795.34 - real number
# uD - alphabetical strings
# Z07x22x6 - alphanumeric
# OMUAbjjBAEgEYwI - alphabetical strings
# yFFOJxCxlIfiyN - alphabetical strings
# 83471923730.14682 - real number
# ZjqMp70dO9 - alphanumeric
# 14096 - integer
# r6yy9xgSsVW4 - alphanumeric
# 201986019 - integer
# 804067545545627 - integer
# 15739.99037 - real number
# 198941641 - integer
# 367957317 - integer
# wsZ3nVpdnLE0 - alphanumeric
# 833843613.91363 - real number
# inlcbFUCWHDx - alphabetical strings
# yXhanN1 - alphanumeric
# 766472 - integer
# 2266089470868 - integer
# 74 - integer
# 225635217135 - integer
# 248423341367.2593 - real number
# 8906005449 - integer
# 234.16079 - real number
# CGG - alphabetical strings
# qjuSuKsm - alphabetical strings
# RFENhiZLXAMtDFU - alphabetical strings
# 694627515060.2355 - real number
# Gh - alphabetical strings
# OqOPWqLuT - alphabetical strings
# smeRMCMqmTRegh - alphabetical strings
# 39500168 - integer
# 7168077552 - integer
# 9686147 - integer
# 346331803.07923 - real number
# LXRWYbAQW - alphabetical strings
# 9222866.75777 - real number
# 75 - integer
# 6026 - integer
# kCfL4Bsm0H5K4W5 - alphanumeric
# 6kK6 - alphanumeric
# 3723311963846 - integer
# WNX - alphabetical strings
# 290053998323032 - integer
# YyBgkFkOZxlT - alphabetical strings
# Sg2Gx8sD2 - alphanumeric
# BRNblixKf5C8 - alphanumeric
# FaUV3COd9 - alphanumeric
# OPGmYVH4 - alphanumeric
# 3766353.89775 - real number
# 9zlVUindX2tGv0 - alphanumeric
# 733414.58547 - real number
# OlZWdvrXBxHb - alphabetical strings
# 16400616.88487 - real number
# 596.6591 - real number
# 8957070762027.9 - real number
# SRV0D2 - alphanumeric
# 69215896 - integer
# 341972266818.6741 - real number
# 75 - integer
# mJJNYqa - alphabetical strings
# 10965.93272 - real number
# eDbyImxFUS - alphabetical strings
# BsxQSWjJpgDmQ - alphabetical strings
# vxpnBreoywlh - alphabetical strings
# 4850960.22658 - real number
# 5VW1s2Ndq9 - alphanumeric
# 549149335 - integer
# dFxA - alphabetical strings
# b9 - alphanumeric
# tQ9 - alphanumeric
# us1pY2 - alphanumeric
# izpa1OZixphkt9 - alphanumeric
# 7719762.75002 - real number
# 28583669487.71535 - real number
# xUOu - alphabetical strings
# 23331309 - integer
# d5868YNeU7 - alphanumeric
# 72 - integer
# Uimtlhw - alphabetical strings
# 13.9611 - real number
# yFJltUbggFcLmte - alphabetical strings
# SCAKugI - alphabetical strings
# 7099.29045 - real number
# 490827228581410 - integer
# rogur2YT0 - alphanumeric
# eHPfRY - alphabetical strings
# dL8 - alphanumeric
# fHpvHZuvPSeyXm - alphabetical strings
# 2470873514125.511 - real number
# lyPtkiN - alphabetical strings
# 450857434 - integer
# vKMbcOtFAXDg - alphabetical strings
# aoriLaMK5 - alphanumeric
# 3314927782924.9326 - real number
# 19613 - integer
# nbQGwh - alphabetical strings
# ztdVmBdsLmPgex - alphabetical strings
# 156.91645 - real number
# 44 - integer
# 112069361490.98323 - real number
# r0hncO2 - alphanumeric
# uQ0 - alphanumeric
# 43503 - integer
# Ii9wabxf3 - alphanumeric
# 2XfZF2n0ge8 - alphanumeric
# P2di1P8bK1 - alphanumeric
# UbPx - alphabetical strings
# 6wyMFU5St0 - alphanumeric
# 234614173.27026 - real number
# 50501502258.2662 - real number
# KGIdqHmGOTksi - alphabetical strings
# 233.24763 - real number
# RIM - alphabetical strings
# OwvHXsy - alphabetical strings
# 1502.75661 - real number
# 223.04637 - real number
# 158 - integer
# wAAvC - alphabetical strings
# BL - alphabetical strings
# wsualpqAixm3 - alphanumeric
# sAczCDl - alphabetical strings
# EPDC5d0fp9 - alphanumeric
# aPP17MKEjj5 - alphanumeric
# 478443644135066 - integer
# 81328398821 - integer
# 8062408422 - integer
# yAPkiz5 - alphanumeric
# fDoQQVEcauqPhM - alphabetical strings
# 1044587818001 - integer
# wf2 - alphanumeric
# 641207.94742 - real number
# 80.71583 - real number
# 309340977 - integer
# lB - alphabetical strings
# WiryqlGUSXq - alphabetical strings
# 7307345008.18609 - real number
# 194632187176276.2 - real number
# 94909 - integer
# RSXeWLgpwfE - alphabetical strings
# gbb - alphabetical strings
# aCxDtesFdYRJqpx - alphabetical strings
# 5717 - integer
# 3957854.75054 - real number
# aiRT1 - alphanumeric
# iTUPyRVFcz - alphabetical strings
# 278942963478 - integer
# 7068950.12164 - real number
# 58047855.36037 - real number
# 35687.9473 - real number
# tYknBRB9jHCfm0 - alphanumeric
# bFPK2 - alphanumeric
# 9842 - integer
# 3274993686.57617 - real number
# WHv - alphabetical strings
# rUpnGjUMmR1 - alphanumeric
# 888442171808528.6 - real number
# 29722501.25327 - real number
# 9II3 - alphanumeric
# 0hdRfC7 - alphanumeric
# vnfqEYCmkUfdR - alphabetical strings
# 6032.97965 - real number
# iIcg5 - alphanumeric
# 2756676 - integer
# 90633781120.31703 - real number
# cD0AJwBx5 - alphanumeric
# 39 - integer
# 9356595.27994 - real number
# 7843.27069 - real number
# XjfO5Hj0 - alphanumeric
# 2517368.64489 - real number
# obEuaTT5hQi5 - alphanumeric
# SwDRrPdWIyic - alphabetical strings
# 125869956939.71692 - real number
# fJRIq8v9Qmr4k9 - alphanumeric
# mPqTq9lu8NJT6h0 - alphanumeric
# DuX3tEMM40f1 - alphanumeric
# 532515148714892.4 - real number
# MYQk - alphabetical strings
# RH3HoVo5 - alphanumeric
# Qyk - alphabetical strings
# r8NsxTN7 - alphanumeric
# 604440.85576 - real number
# QfeAr3haiJwK8 - alphanumeric
# 247346308380 - integer
# 3616520.52743 - real number
# lbLF - alphabetical strings
# 92363196751122 - integer
# GWHQk3 - alphanumeric
# 153 - integer
# 62VUqZ1 - alphanumeric
# 3tFB4Jr8y3i3 - alphanumeric
# ofknaJCUVxGEc - alphabetical strings
# lT9H2ArEa4 - alphanumeric
# 61034.546 - real number
# 832153 - integer
# CEjvnzHfz - alphabetical strings
# 72575.16145 - real number
# 664379675231805.1 - real number
# NwhYrU5jeZ6 - alphanumeric
# 4DxP0 - alphanumeric
# hOkfM - alphabetical strings
# 503 - integer
# 4521993503619.729 - real number
# VBELIhGfN6 - alphanumeric
# LIfknirEZvYXTgt - alphabetical strings
# 3629219 - integer
# 944258963710.3822 - real number
# 31398512350590.215 - real number
# cukcKMN - alphabetical strings
# 1280681022823.5166 - real number
# M3bYpMfVkZ1 - alphanumeric
# xaA9 - alphanumeric
# 37640065 - integer
# 315762 - integer
# BdVsEkrzeJzL - alphabetical strings
# pMp - alphabetical strings
# 661.03434 - real number
# l2yJOVrfNaMAL5 - alphanumeric
# N3U6 - alphanumeric
# 42.32788 - real number
# 997685678749584.9 - real number
# 2990882.71848 - real number
# gP - alphabetical strings
# 9pWjbdh3 - alphanumeric
# 3IoW5WUwZkBi5 - alphanumeric
# 22.71602 - real number
# pbdx5 - alphanumeric
# 8139148 - integer
# lMwQNlCkrfhs9 - alphanumeric
# pSuBruP5 - alphanumeric
# 2412 - integer
# DwTNUwGnau - alphabetical strings
# 309 - integer
# NKtAtQC9 - alphanumeric
# VcBy1 - alphanumeric
# uhVtDfJSzLTLft - alphabetical strings
# 8647112687499.1875 - real number
# SOmbwp - alphabetical strings
# vIJFENAvZzbVL - alphabetical strings
# 2949 - integer
# albxPcsXk - alphabetical strings
# 37026998 - integer
# rMIUBYVxhYNoQOu - alphabetical strings
# 84.44968 - real number
# 182503366705186.4 - real number
# 6681702.68957 - real number
# sTMTrZ - alphabetical strings
# 84414852.55349 - real number
# 9652156 - integer
# MFozYO - alphabetical strings
# ScGllNfaucH6 - alphanumeric
# 817457 - integer
# QB3HMVC2 - alphanumeric
# SLxblg - alphabetical strings
# IkGXhh9rvdT5 - alphanumeric
# 685035503326330 - integer
# 36 - integer
# 53702618675 - integer
# fWXULOAU6i9 - alphanumeric
# abvyQcKll5 - alphanumeric
# 1554156 - integer
# 81 - integer
# LKWr5YTbumK9WF2 - alphanumeric
# 556517809 - integer
# Vls0cgE1 - alphanumeric
# 612.09652 - real number
# 47 - integer
# 938 - integer
# 759874.61895 - real number
# aO46QZzI8 - alphanumeric
# wkMEPpl - alphabetical strings
# 953993056645618 - integer
# Qq1 - alphanumeric
# Lx1hI24jNB9 - alphanumeric
# 243549857570 - integer
# vkEyeCUxPy - alphabetical strings
# GX5 - alphanumeric
# 4267054 - integer
# TbVzUd73HZAIB2 - alphanumeric
# R12kCAaNKRcao4 - alphanumeric
# 581921971.70978 - real number
# 57460099624418 - integer
# 1872421684.22306 - real number
# PnPPOrPSj - alphabetical strings
# 2zZlDwPl1 - alphanumeric
# tvrGRQkSRxB8IE5 - alphanumeric
# 5iErrAL2evuF3 - alphanumeric
# HXxW0F9 - alphanumeric
# 7217039788.59945 - real number
# MeCvv0yiu7G0gm0 - alphanumeric
# 206789178418859.9 - real number
# LpBpfoKskBc - alphabetical strings
# 733377496382 - integer
# 180258727383.37643 - real number
# 37914703638233.18 - real number
# 23712271257183 - integer
# 4190 - integer
# 453533071.62226 - real number
# LIP - alphabetical strings
# 0 - integer
# 1rsk6XLJlu8R8 - alphanumeric
# ccOd - alphabetical strings
# kmCBSFdD - alphabetical strings
# 97972796530.7985 - real number
# 8250137.4104 - real number
# lgxOQeGgFU8w5 - alphanumeric
# 369020959 - integer
# KtZJtDW84iRws7 - alphanumeric
# 79917420395.27794 - real number
# 65730745 - integer
# 815766952931.1079 - real number
# 8416816777101.329 - real number
# 0zCnEoU3 - alphanumeric
# EExP9 - alphanumeric
# 37325868997009 - integer
# sPAmxXUt - alphabetical strings
# flN9 - alphanumeric
# 84653696.24641 - real number
# cbEjxr8 - alphanumeric
# xe - alphabetical strings
# 8948305124.47997 - real number
# 60 - integer
# SO2r6Yc9 - alphanumeric
# ts7Q8OL3Ipgwsr8 - alphanumeric
# vw - alphabetical strings
# 348512220031168 - integer
# 233139625379.2961 - real number
# 9788 - integer
# 95185 - integer
# oZuOo - alphabetical strings
# wnuIRwpzMvxV - alphabetical strings
# 1554 - integer
# DT9kkpijoOO3 - alphanumeric
# CnHhjYAgw - alphabetical strings
# 6376732228 - integer
# 127508371 - integer
# LqUzyivz5xHy7 - alphanumeric
# eTnoRE - alphabetical strings
# PU4 - alphanumeric
# SBqnzPRWyqOaA - alphabetical strings
# PJjLpFwzcu - alphabetical strings
# wAeaTMMYuUmpb - alphabetical strings
# VLRP7 - alphanumeric
# gi0ZUsr1NsJz3 - alphanumeric
# 45956199526700.336 - real number
# 41.49103 - real number
# 4237467827619.5786 - real number
# 4879.58663 - real number
# YjSrUxkKwU - alphabetical strings
# XEJmwNwK - alphabetical strings
# 22.80505 - real number
# 1936098206.94199 - real number
# hz0yyAWtSbHs8 - alphanumeric
# 15604158360 - integer
# cQaT - alphabetical strings
# 68111 - integer
# 8 - integer
# 44468509332.6319 - real number
# 20409692.28341 - real number
# 67839251259266 - integer
# 95146 - integer
# 245826301.10076 - real number
# LFl - alphabetical strings
# 56742321269506 - integer
# Ap - alphabetical strings
# 300.96026 - real number
# pyMke - alphabetical strings
# 92187.25165 - real number
# QuCP - alphabetical strings
# 1280485658 - integer
# Y3BFJzXXjWRNe0 - alphanumeric
# 88820899.91237 - real number
# 570245768 - integer
# 799584766 - integer
# 153224815806.04642 - real number
# MqTNqDE5aeTb5 - alphanumeric
# 840 - integer
# 471578748879 - integer
# 52275065.27621 - real number
# uf - alphabetical strings
# 711141078.28832 - real number
# 29411.88775 - real number
# jKA - alphabetical strings
# wdSiLqPxCs - alphabetical strings
# cFzzt1DsW2x8 - alphanumeric
# azEUngfu - alphabetical strings
# Cw - alphabetical strings
# 105349259925409.33 - real number
# VkfofxfDXnn - alphabetical strings
# ...
# jFjjhtU - alphabetical strings
# 2511566865.72815 - real number
# 71371173.25046 - real number
# 6492308595304.383 - real number
# 626787507177112.0 - real number
# xzhVlzREYHPPL - alphabetical strings
# lVHdRs - alphabetical strings
# 531264314 - integer
# 980721085288053.0 - real number
# RDuTCuF - alphabetical strings
# fgPSSLkkgDq1 - alphanumeric
# f3 - alphanumeric
# 3147360101775.5083 - real number
# bkfNkxipNx - alphabetical strings
# ry9 - alphanumeric
# 251.06138 - real number
# uT0L3X7 - alphanumeric
# dyizX - alphabetical strings
# gyFcRy - alphabetical strings
# QUgyGY0 - alphanumeric
# 7630252954 - integer
# 592951978230.786 - real number
# 421137316297.1011 - real number
# uK3InXe8 - alphanumeric
# 95336687394675 - integer
# 5539450407.62516 - real number
# S9vssZ6 - alphanumeric
# 74702308768.59674 - real number
# dW0rzXDjTL2 - alphanumeric
# 9643859698251.18 - real number
# 99999059531544 - integer
# 8aGQ5 - alphanumeric
# lZdi7 - alphanumeric
# 733719052663602 - integer
# 4796647994135 - integer
# 8373690273.01454 - real number
# 277800337 - integer
# 518480971710 - integer
# 801930 - integer
# 11779503740.66935 - real number
# DLVfSs - alphabetical strings
# vVWwASvx - alphabetical strings
# 3108955110031 - integer
# AOazJTHpCIMn5 - alphanumeric
# 97.28738 - real number
# VQHPOx - alphabetical strings
# 372812524262.05566 - real number
# 6969825931968.088 - real number
# 120425820.5396 - real number
# krOS3 - alphanumeric
# 2158753695515.3953 - real number
# RudGFfjhASnzD - alphabetical strings
# Yr0 - alphanumeric
# 80962 - integer
# fVUCwXdhjY - alphabetical strings
# HhvenSCCkTEa - alphabetical strings
# QJg - alphabetical strings
# N5 - alphanumeric
# gqNEj - alphabetical strings
# 99 - integer
# swY - alphabetical strings
# 1123671.5467 - real number
# ZPcvkoWDYwpCX - alphabetical strings
# OZCslHQrFlByq - alphabetical strings
# 783376350.13485 - real number
# 4829 - integer
# 67104874 - integer
# 358643957395523.1 - real number
# 3094389.34448 - real number
# 5890029426 - integer
# 5072474 - integer
# oFO3 - alphanumeric
# 5875497 - integer
# 8565315 - integer
# 52220896332973 - integer
# 6695.69333 - real number
# 83741445401 - integer
# seW1 - alphanumeric
# 7OLKVYEHd5IAT8 - alphanumeric
# 6992968.72102 - real number
# 2veClejppmJ1h6 - alphanumeric
# 48883995212 - integer
# Mhz - alphabetical strings
# WEYSb3Fv4 - alphanumeric
# 830748614 - integer
# GTvC1 - alphanumeric
# 7515789726 - integer
# bjMBXLvv - alphabetical strings
# NubkNsLNQBAghT4 - alphanumeric
# 469.69046 - real number
# wpTIqdB - alphabetical strings
# vYCaeVfUj - alphabetical strings
# pR7UnT1 - alphanumeric
# 160 - integer
# wLECcRVOMvD - alphabetical strings
# 92842 - integer
# 743630932.45646 - real number
# 70604977.05383 - real number
# wUVWjWsal - alphabetical strings
# 5812555051 - integer
# nG - alphabetical strings
# 413.07074 - real number
# PCHTNdhgpmig5 - alphanumeric
# J4 - alphanumeric
# sdrejJWWVQyEf - alphabetical strings
# 829.16926 - real number
# l7zs3uhEbfYpV0 - alphanumeric
# B2 - alphanumeric
# w2Ap7 - alphanumeric
# IXxZCj - alphabetical strings
# xoA - alphabetical strings
# 6y56XJi8 - alphanumeric
# JaVAT5 - alphanumeric
# 59742.04198 - real number
# 0gOCVnRYuB8tbk8 - alphanumeric
# yVxdHGxvU - alphabetical strings
# Ns - alphabetical strings
# yg4lqYN4 - alphanumeric
# ObkvOq - alphabetical strings
# RSo - alphabetical strings
# 2973489 - integer
# 887.34722 - real number
# Hm8O3 - alphanumeric
# 8SKSFESx6Q7 - alphanumeric
# GecrfDXCissE - alphabetical strings
# 3011557.77968 - real number
# vY3uO61cU8 - alphanumeric
# 583037775719.8923 - real number
# 9976392 - integer
# j0 - alphanumeric
# nN - alphabetical strings
# GnLYL - alphabetical strings
# 977281703622347.9 - real number
# w3K0d8i6 - alphanumeric
# 45090751910705.375 - real number
# aq - alphabetical strings
# 32447357 - integer
# fjMjVzcaMLjZx - alphabetical strings
# 63030 - integer
# vbEAn9 - alphanumeric
# 98319282587 - integer
# bqNnDsGBAA - alphabetical strings
# 67.90204 - real number
# tsOQSEGlE - alphabetical strings
# Lo6sp8 - alphanumeric
# x8 - alphanumeric
# 9884916967 - integer
# 2 - integer
# mz - alphabetical strings
# LgpVKmFvsJjO - alphabetical strings
# 238076556.83447 - real number
# loJB6AfAZtD0 - alphanumeric
# 275548349013 - integer
# 360 - integer
# QIvFbphCvqYC - alphabetical strings
# 679825789 - integer
# jHLJW2Oep7gT3 - alphanumeric
# 9771944177.10559 - real number
# RxbDHFP - alphabetical strings
# 370638.613 - real number
# tCqul - alphabetical strings
# 966537.23433 - real number
# iao2uvj4 - alphanumeric
# MB - alphabetical strings
# ZidaDAXpPBLf1 - alphanumeric
# 70433393658671 - integer
# EMhZbcPzA - alphabetical strings
# 5050957284.55125 - real number
# dIkjlnix7 - alphanumeric
# nxnpEuBXwTttEz - alphabetical strings
# 16.62771 - real number
# HejfC2 - alphanumeric
# t3YWM0h5 - alphanumeric
# jMB5L952bsZsR0 - alphanumeric
# 40.32152 - real number
# 457631854845853.44 - real number
# 8259171321.01362 - real number
# 65 - integer
# 5119615156 - integer
# 5941545 - integer
# Ng9 - alphanumeric
# xwpJKucZGI - alphabetical strings
# 56783548 - integer
# 3001219572027 - integer
# 5255886019.09029 - real number
# gERQp - alphabetical strings
# 619655556.5408 - real number
# awzGld2UX9FmjQ4 - alphanumeric
# Zz1OGTwpbk6 - alphanumeric
# 8eT5t6fGe3p9 - alphanumeric
# 140955915828365.2 - real number
# VSJjMpLudP - alphabetical strings
# 4528 - integer
# 69279462863.97217 - real number
# ZjxboDEtV3 - alphanumeric
# 8781264107.81614 - real number
# 8Px5Zxp3 - alphanumeric
# 4715.85002 - real number
# 908704193 - integer
# 2040906666623 - integer
# 474 - integer
# HTzyGH8SzbSWXl7 - alphanumeric
# IibKckdmWsdQ - alphabetical strings
# 5572103 - integer
# qtPFbKwSbdUj - alphabetical strings
# 2795.81452 - real number
# 43515403.5846 - real number
# hQyCLrQfMKGWEu - alphabetical strings
# 408864745.3655 - real number
# c0 - alphanumeric
# Laoubb6 - alphanumeric
# 8477717 - integer
# 2524215 - integer
# Ki3Kd7 - alphanumeric
# HQRcqL - alphabetical strings
# 68237526799 - integer
# 50508893617783.39 - real number
# e53CDsx5 - alphanumeric
# 6947437447659.633 - real number
# 238386992274.13196 - real number
# 835 - integer
# qTPeOAOuyujwxRE - alphabetical strings
# 5810971380295.875 - real number
# JM2am5op5 - alphanumeric
# 92264268228 - integer
# 46493.8818 - real number
# 59460567 - integer
# IvWvmchmyJwhV - alphabetical strings
# CZWZfzF - alphabetical strings
# yFMTnTHMsQAsOk6 - alphanumeric
# 21663255422002.547 - real number
# ZlWx - alphabetical strings
# 389114880040.188 - real number
# MIFdNvwSj - alphabetical strings
# bHQZzT - alphabetical strings
# 921888961123190 - integer
# 288303662.32496 - real number
# mxYbQECplUR - alphabetical strings
# 21495825103 - integer
# OoOXPwRViyukQbg - alphabetical strings
# gMzgOe9 - alphanumeric
# 254561106215 - integer
# iaieRAmEveq - alphabetical strings
# 155.54724 - real number
# 90938 - integer
# VidtZ1 - alphanumeric
# 48057707487.46 - real number
# rKuogftGPGJsH - alphabetical strings
# 506834120.98895 - real number
# WIdHio9 - alphanumeric
# TP - alphabetical strings
# ygMXqo1 - alphanumeric
# 3vFBMIsE0 - alphanumeric
# PHYHjLcXqYpY - alphabetical strings
# kR8DmAoh1 - alphanumeric
# 196285464368916.6 - real number
# 721488428540120.4 - real number
# vBI7FnbQdJ6goq5 - alphanumeric
# SxDR5ni5Cosv9 - alphanumeric
# 236127606936893 - integer
# QHchHCdevx - alphabetical strings
# 9008861069.63514 - real number
# ieVXUCEC - alphabetical strings
# DoCSgoxv9 - alphanumeric
# nEYhOhAXDQS - alphabetical strings
# 49 - integer
# DEaiL - alphabetical strings
# VS - alphabetical strings
# zoCYSF - alphabetical strings
# Zzh82S5p6 - alphanumeric
# 9nw1RC0 - alphanumeric
# 10091.42579 - real number
# 76392.0738 - real number
# 0.34991 - real number
# 1191895024835 - integer
# 62549156185 - integer
# 750.68993 - real number
# bIVsLdG - alphabetical strings
# 171711 - integer
# oAqrGnyRInplr - alphabetical strings
# 4963 - integer
# 21035290 - integer
# 5058709 - integer
# 201465398270272.44 - real number
# 11 - integer
# XVZCvwhHIsLwGk - alphabetical strings
# 14 - integer
# eSEpBvN5UWRpIa4 - alphanumeric
# hpnWbrT - alphabetical strings
# VMKgo - alphabetical strings
# 61698799316 - integer
# 49236182018.44345 - real number
# 7856975.5403 - real number
# I6qtirsrOM2 - alphanumeric
# EpJsKJTmmcK - alphabetical strings
# aNy3 - alphanumeric
# 9576822409.72584 - real number
# WYmoIBzZVg - alphabetical strings
# k7 - alphanumeric
# 5110726 - integer
# fFzgWuYscs - alphabetical strings
# usdCHXgPW - alphabetical strings
# UVbJlAO - alphabetical strings
# 4524 - integer
# 80 - integer
# 4099748762.60741 - real number
# AnA - alphabetical strings
# 9991783839.98178 - real number
# 471 - integer
# wI8 - alphanumeric
# SgwNeFHVfFGZU - alphabetical strings
# KdSBLoiZoH9 - alphanumeric
# 4670231810289.061 - real number
# 604677194151641.5 - real number
# 7816679271.36324 - real number
# TqEsQRCELgBZlkS - alphabetical strings
# 466 - integer
# XUUYdIr - alphabetical strings
# 9947378925886.324 - real number
# 9115253286.67535 - real number
# 112975036 - integer
# 78093001247.16182 - real number
# 87934180948.98175 - real number
# 72196090 - integer
# 95667.68135 - real number
# 463166241 - integer
# 84874707856.51334 - real number
# BMEzIIEO - alphabetical strings
# N3QVi25rTAeBo4 - alphanumeric
# 228029.84068 - real number
# 5097937909580 - integer
# S9 - alphanumeric
# 76862432 - integer
# Sg7 - alphanumeric
# IDHJI2wHz4 - alphanumeric
# Ucfb5f01hBg9 - alphanumeric
# 872167654484.72 - real number
# 5593196920 - integer
# 3281796962586 - integer
# 5q3RqCVAL8Kcm6 - alphanumeric
# xvHaEGTswIKGR - alphabetical strings
# ydbRhTRInH - alphabetical strings
# UeOvGTIdXfPFF - alphabetical strings
# 194884931236.44635 - real number
# GwczkCuEbCNOi9 - alphanumeric
# 4141.77238 - real number
# 876 - integer
# 75243888.81003 - real number
# 7812294685092.467 - real number
# 6298398 - integer
# RQLwbfRU - alphabetical strings
# YgfMO7lvU6 - alphanumeric
# 52522433496065 - integer
# bMR1 - alphanumeric
# uIcWY0 - alphanumeric
# pnJMtQFRaMDO9 - alphanumeric
# AzWfWsa - alphabetical strings
# mE3GaGm0 - alphanumeric
# 35 - integer
# 60423 - integer
# 94980542087.97205 - real number
# 74665588933455 - integer
# qBU - alphabetical strings
# 846690322.72764 - real number
# 88038445036614 - integer
# PZwPNCJNhJO - alphabetical strings
# sIZVdm8jhAVMAa3 - alphanumeric
# 78062429870257 - integer
# V1 - alphanumeric
# 2840122.45548 - real number
# 2402213.76103 - real number
# RrpIFfCs5 - alphanumeric
# 1799 - integer
# RtUob6QPkFFLFc8 - alphanumeric
# cEToquXmZ - alphabetical strings
# ZBa6F9tHw1 - alphanumeric
# 8235546196.70133 - real number
# 1048023185.94927 - real number
# 26436856135770 - integer
# lNxIgDILdj - alphabetical strings
# zsn1 - alphanumeric
# 63116574804408.21 - real number
# 3694786647055 - integer
# sJ9Z8Cvhqjhy7 - alphanumeric
# uPt6v2 - alphanumeric
# 21.90404 - real number
# 640487.98787 - real number
# QNiz4 - alphanumeric
# 47165719.77924 - real number
# GMwJjQscgEPL9 - alphanumeric
# nJJmTOJVNAqfg - alphabetical strings
# ThW20nDkHEqKM6 - alphanumeric
# eUUlROx0a3ANY7 - alphanumeric
# uTcjdr - alphabetical strings
# sO538vlyOxG1 - alphanumeric
# 848485132080937 - integer
# 35.10107 - real number
# fiQZJnTkSebr - alphabetical strings
# 11XH8 - alphanumeric
# 9771628811.80482 - real number
# pnYeyoaMyYSzXzR - alphabetical strings
# 841551648 - integer
# 0lLuVhOPp7 - alphanumeric
# 67309757266 - integer
# 78 - integer
# 117.12247 - real number
# 556353605762357.7 - real number
# Gf - alphabetical strings
# 4693324 - integer
# 961658063946.0682 - real number
# 837146314.16777 - real number
# 39366048863.80344 - real number
# 99128393805.78989 - real number
# 914001404385274.0 - real number
# 111270699538 - integer
# 5ib9QJ4ns0 - alphanumeric
# 863295 - integer
# 42.29599 - real number
# 147553.5454 - real number
# o2KyFyLj8 - alphanumeric
# 2540446291071 - integer
# 17716678003061.016 - real number
# B6YBjX6nlJy3 - alphanumeric
# i3 - alphanumeric
# mdi - alphabetical strings
# fWPaK - alphabetical strings
# gVFY4 - alphanumeric
# xUGc6 - alphanumeric
# 5391161.42677 - real number
# gsQTGQ186Yenu8 - alphanumeric
# UwHbwVEw7Dsz9 - alphanumeric
# nJ - alphabetical strings
# 87oZ6 - alphanumeric
# V1 - alphanumeric
# Q6 - alphanumeric
# 037jFUgSn8 - alphanumeric
# d6 - alphanumeric
# 58381939946.93426 - real number
# FIaXJucE - alphabetical strings
# 278.80962 - real number
# eBxCENU - alphabetical strings
# dowjR - alphabetical strings
# 7418894076 - integer
# EuWIQW - alphabetical strings
# W0 - alphanumeric
# TnH4A1 - alphanumeric
# mwbmlI9 - alphanumeric
# WfeKV6VtD7H9 - alphanumeric
# neA7NNUKKKiVcW1 - alphanumeric
# 77409729 - integer
# OSHbTBbmri8 - alphanumeric
# mhZg - alphabetical strings
# BSjvRXWv - alphabetical strings
# 737201 - integer
# nZ - alphabetical strings
# dMKZI9 - alphanumeric
# rLpAxGhF - alphabetical strings
# 785865382049 - integer
# 8903501.38762 - real number
# YTtXPNSLBzx - alphabetical strings
# iChukCxlCl - alphabetical strings
# 356067751.89898 - real number
# 58347966636174 - integer
# 508239749.3505 - real number
# 300417623.16913 - real number
# JuZF9BlyGS6 - alphanumeric
# 62562 - integer
# ENKYoAlvUuvB - alphabetical strings
# 50.07244 - real number
# 134432 - integer
# 7150285773791.012 - real number
# mGWG - alphabetical strings
# sjXXFrCOBzp - alphabetical strings
# 78 - integer
# USPnm6 - alphanumeric
# a1 - alphanumeric
# cD9 - alphanumeric
# 769104049934983 - integer
# JsmyPSGEgyEc - alphabetical strings
# 5302129.85514 - real number
# hLjcQriAzwg - alphabetical strings
# eHMcoAZ - alphabetical strings
# 7SzOBPVLv7 - alphanumeric
# 52554843971606 - integer
# 850380.47202 - real number
# 6689958.52093 - real number
# Zn1 - alphanumeric
# 547959743784331.75 - real number
# 91264718 - integer
# 256.05115 - real number
# 39.32512 - real number
# 5653073 - integer
# 47072675394463.66 - real number
# uASlzBEW8zhD2 - alphanumeric
# 516722523827.6466 - real number
# 1857975275 - integer
# Af1 - alphanumeric
# XLKX - alphabetical strings
# 271465513329.60233 - real number
# q3Kbw4 - alphanumeric
# 58319.30255 - real number
# tUXxyvqILPIZZ - alphabetical strings
# qibFrvT0 - alphanumeric
# qlbBBJ - alphabetical strings
# 5TmfVwoUUr9 - alphanumeric
# 3207561444463 - integer
# BWFJm - alphabetical strings
# TXyINv - alphabetical strings
# 4852152722211.961 - real number
# 5654043 - integer
# pVtPvsFr - alphabetical strings
# 197 - integer
# 495 - integer
# RyDKefa - alphabetical strings
# 681323765185000.9 - real number
# 713665370.56824 - real number
# fanMUbwgeP - alphabetical strings
# RtvOCHclKAN - alphabetical strings
# 0 - integer
# 8759096567862.412 - real number
# 5986529660 - integer
# 25.4794 - real number
# ZjwLtbOJF5Uyr3 - alphanumeric
# REwo - alphabetical strings
# TAc - alphabetical strings
# OXL - alphabetical strings
# 620055749.33296 - real number
# Jv7TGnM9 - alphanumeric
# 2G1 - alphanumeric
# 59843.82492 - real number
# RnZQm5 - alphanumeric
# seE - alphabetical strings
# WsKFH1cBme9 - alphanumeric
# WEFHbws44nt8 - alphanumeric
# p5PEoaKE5 - alphanumeric
# chbANY - alphabetical strings
# rwt - alphabetical strings
# 38544 - integer
# pJ5fb8 - alphanumeric
# 62735569714276 - integer
# cic9 - alphanumeric
# mWEb1BXKfGV7 - alphanumeric
# 2043704913531.4766 - real number
# mTGUZ4Ys2lhN1 - alphanumeric
# 73532189372202 - integer
# pfMmMSQzgOsJnU - alphabetical strings
# 18 - integer
# 74268.28421 - real number
# VWXmkScwxuTp - alphabetical strings
# ZAcfHeNBf793T0 - alphanumeric
# 4803081826007 - integer
# QWRxfWGXX - alphabetical strings
# QdRXNh - alphabetical strings
# 8856126 - integer
# 922398 - integer
# 246071521892.83298 - real number
# VzITueHLJ - alphabetical strings
# wp6GEQ5ieH0 - alphanumeric
# 687 - integer
# 214797.58891 - real number
# 400069001.65276 - real number
# LxBkHCDg - alphabetical strings
# 537519.08855 - real number
# RXdxden - alphabetical strings
# UK1k2 - alphanumeric
# PAahSHY - alphabetical strings
# BzUw6 - alphanumeric
# PfTRVptaBDOExDV - alphabetical strings
# LMZJtlrTB - alphabetical strings
# BhGaF - alphabetical strings
# TITloU - alphabetical strings
# 43418 - integer
# uOV9U5 - alphanumeric
# lIewwPXJZECdH - alphabetical strings
# 6025296.6638 - real number
# K3FSi5 - alphanumeric
# zpfz2 - alphanumeric
# 96648099 - integer
# JgyBVN9VlTyk9 - alphanumeric
# 12081461350727 - integer
# 49721658174954 - integer
# SfPOceh - alphabetical strings
# 14095205 - integer
# YuJaATwejshE - alphabetical strings
# 39414 - integer
# j7Nt8JUy24t1 - alphanumeric
# aLBZOHn1 - alphanumeric
# JPZ5bhQUcgSEh8 - alphanumeric
# 61.74785 - real number
# ZbsYFqHVuSOTjHX - alphabetical strings
# 738 - integer
# LqPPmJvBSulKZ - alphabetical strings
# 56 - integer
# ikg7As9 - alphanumeric
# Wdt - alphabetical strings
# WhojKvvHBznS - alphabetical strings
# KoONt - alphabetical strings
# TMdA - alphabetical strings
# bO2 - alphanumeric
# 6531.35969 - real number
# 478 - integer
# 1052549.55477 - real number
# 326961 - integer
# 491088480126548 - integer
# eCYYOv9KUXsa5 - alphanumeric
